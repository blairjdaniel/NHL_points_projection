# %%
import pandas as pd 
import numpy as np 
import os 
import requests
from pprint import pprint
import matplotlib.pyplot as plt
import seaborn as sns

# from nhlpy import NHLClient

# %%
# Function to get game logs for a specific season
def get_game_log(player_id, season):
    url = f"https://api-web.nhle.com/v1/player/{player_id}/game-log/{season}/2"
    response = requests.get(url)
    return response.json()

# %%
# Set variables
season = 20232024
player_id = 8471214

# Get the Game logs
game_logs = get_game_log(player_id, season)

pprint(game_logs)
# Out:
# {'gameLog': [{'assists': 0,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2024-04-16',
#               'gameId': 2023021299,
#               'gameWinningGoals': 0,
#               'goals': 1,
#               'homeRoadFlag': 'R',
#               'opponentAbbrev': 'PHI',
#               'opponentCommonName': {'default': 'Flyers'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': 1,
#               'points': 1,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 0,
#               'shifts': 22,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 1,
#               'teamAbbrev': 'WSH',
#               'toi': '14:55'},
#              {'assists': 0,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2024-04-15',
#               'gameId': 2023021291,
#               'gameWinningGoals': 0,
#               'goals': 0,
#               'homeRoadFlag': 'H',
#               'opponentAbbrev': 'BOS',
#               'opponentCommonName': {'default': 'Bruins'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': 0,
#               'points': 0,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 0,
#               'shifts': 21,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 1,
#               'teamAbbrev': 'WSH',
#               'toi': '18:00'},
#              {'assists': 0,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2024-04-13',
#               'gameId': 2023021275,
#               'gameWinningGoals': 0,
#               'goals': 0,
#               'homeRoadFlag': 'H',
#               'opponentAbbrev': 'TBL',
#               'opponentCommonName': {'default': 'Lightning'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': -1,
#               'points': 0,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 0,
#               'shifts': 22,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 2,
#               'teamAbbrev': 'WSH',
#               'toi': '19:16'},
#              {'assists': 1,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2024-04-11',
#               'gameId': 2023021255,
#               'gameWinningGoals': 0,
#               'goals': 0,
#               'homeRoadFlag': 'R',
#               'opponentAbbrev': 'BUF',
#               'opponentCommonName': {'default': 'Sabres'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': -1,
#               'points': 1,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 0,
#               'shifts': 21,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 3,
#               'teamAbbrev': 'WSH',
#               'toi': '17:21'},
#              {'assists': 0,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2024-04-09',
#               'gameId': 2023021240,
#               'gameWinningGoals': 1,
#               'goals': 1,
#               'homeRoadFlag': 'R',
#               'opponentAbbrev': 'DET',
#               'opponentCommonName': {'default': 'Red Wings'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': 1,
#               'points': 1,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 0,
#               'shifts': 23,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 2,
#               'teamAbbrev': 'WSH',
#               'toi': '15:11'},
#              {'assists': 0,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2024-04-07',
#               'gameId': 2023021232,
#               'gameWinningGoals': 0,
#               'goals': 0,
#               'homeRoadFlag': 'H',
#               'opponentAbbrev': 'OTT',
#               'opponentCommonName': {'default': 'Senators', 'fr': 'Sénateurs'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': -1,
#               'points': 0,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 0,
#               'shifts': 22,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 2,
#               'teamAbbrev': 'WSH',
#               'toi': '23:08'},
#              {'assists': 0,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2024-04-05',
#               'gameId': 2023021212,
#               'gameWinningGoals': 0,
#               'goals': 2,
#               'homeRoadFlag': 'R',
#               'opponentAbbrev': 'CAR',
#               'opponentCommonName': {'default': 'Hurricanes'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': 1,
#               'points': 2,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 0,
#               'shifts': 22,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 4,
#               'teamAbbrev': 'WSH',
#               'toi': '19:37'},
#              {'assists': 0,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2024-04-04',
#               'gameId': 2023021206,
#               'gameWinningGoals': 0,
#               'goals': 1,
#               'homeRoadFlag': 'H',
#               'opponentAbbrev': 'PIT',
#               'opponentCommonName': {'default': 'Penguins'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': -2,
#               'points': 1,
#               'powerPlayGoals': 1,
#               'powerPlayPoints': 1,
#               'shifts': 22,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 8,
#               'teamAbbrev': 'WSH',
#               'toi': '22:21'},
#              {'assists': 1,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2024-04-02',
#               'gameId': 2023021189,
#               'gameWinningGoals': 0,
#               'goals': 0,
#               'homeRoadFlag': 'R',
#               'opponentAbbrev': 'BUF',
#               'opponentCommonName': {'default': 'Sabres'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': -2,
#               'points': 1,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 1,
#               'shifts': 19,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 3,
#               'teamAbbrev': 'WSH',
#               'toi': '18:58'},
#              {'assists': 0,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2024-03-30',
#               'gameId': 2023021176,
#               'gameWinningGoals': 0,
#               'goals': 0,
#               'homeRoadFlag': 'H',
#               'opponentAbbrev': 'BOS',
#               'opponentCommonName': {'default': 'Bruins'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': 0,
#               'points': 0,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 0,
#               'shifts': 22,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 3,
#               'teamAbbrev': 'WSH',
#               'toi': '21:55'},
#              {'assists': 0,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2024-03-28',
#               'gameId': 2023021155,
#               'gameWinningGoals': 0,
#               'goals': 0,
#               'homeRoadFlag': 'R',
#               'opponentAbbrev': 'TOR',
#               'opponentCommonName': {'default': 'Maple Leafs'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': -1,
#               'points': 0,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 0,
#               'shifts': 22,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 2,
#               'teamAbbrev': 'WSH',
#               'toi': '18:27'},
#              {'assists': 0,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2024-03-26',
#               'gameId': 2023021140,
#               'gameWinningGoals': 0,
#               'goals': 0,
#               'homeRoadFlag': 'H',
#               'opponentAbbrev': 'DET',
#               'opponentCommonName': {'default': 'Red Wings'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': 1,
#               'points': 0,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 0,
#               'shifts': 28,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 4,
#               'teamAbbrev': 'WSH',
#               'toi': '22:28'},
#              {'assists': 0,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2024-03-24',
#               'gameId': 2023021124,
#               'gameWinningGoals': 0,
#               'goals': 2,
#               'homeRoadFlag': 'H',
#               'opponentAbbrev': 'WPG',
#               'opponentCommonName': {'default': 'Jets'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': 2,
#               'points': 2,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 0,
#               'shifts': 29,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 5,
#               'teamAbbrev': 'WSH',
#               'toi': '21:37'},
#              {'assists': 1,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2024-03-22',
#               'gameId': 2023021109,
#               'gameWinningGoals': 0,
#               'goals': 1,
#               'homeRoadFlag': 'H',
#               'opponentAbbrev': 'CAR',
#               'opponentCommonName': {'default': 'Hurricanes'},
#               'otGoals': 0,
#               'pim': 2,
#               'plusMinus': 0,
#               'points': 2,
#               'powerPlayGoals': 1,
#               'powerPlayPoints': 2,
#               'shifts': 27,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 5,
#               'teamAbbrev': 'WSH',
#               'toi': '22:08'},
#              {'assists': 0,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2024-03-20',
#               'gameId': 2023021095,
#               'gameWinningGoals': 0,
#               'goals': 2,
#               'homeRoadFlag': 'H',
#               'opponentAbbrev': 'TOR',
#               'opponentCommonName': {'default': 'Maple Leafs'},
#               'otGoals': 0,
#               'pim': 2,
#               'plusMinus': 1,
#               'points': 2,
#               'powerPlayGoals': 1,
#               'powerPlayPoints': 1,
#               'shifts': 24,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 2,
#               'teamAbbrev': 'WSH',
#               'toi': '15:06'},
#              {'assists': 0,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2024-03-18',
#               'gameId': 2023021080,
#               'gameWinningGoals': 1,
#               'goals': 2,
#               'homeRoadFlag': 'R',
#               'opponentAbbrev': 'CGY',
#               'opponentCommonName': {'default': 'Flames'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': 0,
#               'points': 2,
#               'powerPlayGoals': 2,
#               'powerPlayPoints': 2,
#               'shifts': 23,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 5,
#               'teamAbbrev': 'WSH',
#               'toi': '16:51'},
#              {'assists': 0,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2024-03-16',
#               'gameId': 2023021072,
#               'gameWinningGoals': 1,
#               'goals': 1,
#               'homeRoadFlag': 'R',
#               'opponentAbbrev': 'VAN',
#               'opponentCommonName': {'default': 'Canucks'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': 1,
#               'points': 1,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 0,
#               'shifts': 24,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 1,
#               'teamAbbrev': 'WSH',
#               'toi': '19:13'},
#              {'assists': 0,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2024-03-14',
#               'gameId': 2023021056,
#               'gameWinningGoals': 0,
#               'goals': 0,
#               'homeRoadFlag': 'R',
#               'opponentAbbrev': 'SEA',
#               'opponentCommonName': {'default': 'Kraken'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': 0,
#               'points': 0,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 0,
#               'shifts': 22,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 3,
#               'teamAbbrev': 'WSH',
#               'toi': '18:33'},
#              {'assists': 1,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2024-03-13',
#               'gameId': 2023021043,
#               'gameWinningGoals': 0,
#               'goals': 0,
#               'homeRoadFlag': 'R',
#               'opponentAbbrev': 'EDM',
#               'opponentCommonName': {'default': 'Oilers'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': 0,
#               'points': 1,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 1,
#               'shifts': 20,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 7,
#               'teamAbbrev': 'WSH',
#               'toi': '20:17'},
#              {'assists': 0,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2024-03-11',
#               'gameId': 2023021029,
#               'gameWinningGoals': 0,
#               'goals': 0,
#               'homeRoadFlag': 'R',
#               'opponentAbbrev': 'WPG',
#               'opponentCommonName': {'default': 'Jets'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': -1,
#               'points': 0,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 0,
#               'shifts': 25,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 2,
#               'teamAbbrev': 'WSH',
#               'toi': '19:14'},
#              {'assists': 1,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2024-03-09',
#               'gameId': 2023021017,
#               'gameWinningGoals': 0,
#               'goals': 0,
#               'homeRoadFlag': 'H',
#               'opponentAbbrev': 'CHI',
#               'opponentCommonName': {'default': 'Blackhawks'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': 0,
#               'points': 1,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 1,
#               'shifts': 17,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 3,
#               'teamAbbrev': 'WSH',
#               'toi': '17:45'},
#              {'assists': 1,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2024-03-07',
#               'gameId': 2023020998,
#               'gameWinningGoals': 0,
#               'goals': 1,
#               'homeRoadFlag': 'R',
#               'opponentAbbrev': 'PIT',
#               'opponentCommonName': {'default': 'Penguins'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': 1,
#               'points': 2,
#               'powerPlayGoals': 1,
#               'powerPlayPoints': 1,
#               'shifts': 16,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 1,
#               'teamAbbrev': 'WSH',
#               'toi': '18:43'},
#              {'assists': 1,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2024-03-03',
#               'gameId': 2023020969,
#               'gameWinningGoals': 0,
#               'goals': 0,
#               'homeRoadFlag': 'H',
#               'opponentAbbrev': 'ARI',
#               'opponentCommonName': {'default': 'Coyotes'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': -1,
#               'points': 1,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 1,
#               'shifts': 20,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 8,
#               'teamAbbrev': 'WSH',
#               'toi': '20:58'},
#              {'assists': 0,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2024-03-01',
#               'gameId': 2023020954,
#               'gameWinningGoals': 0,
#               'goals': 1,
#               'homeRoadFlag': 'H',
#               'opponentAbbrev': 'PHI',
#               'opponentCommonName': {'default': 'Flyers'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': 2,
#               'points': 1,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 0,
#               'shifts': 22,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 2,
#               'teamAbbrev': 'WSH',
#               'toi': '17:43'},
#              {'assists': 1,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2024-02-27',
#               'gameId': 2023020927,
#               'gameWinningGoals': 0,
#               'goals': 0,
#               'homeRoadFlag': 'R',
#               'opponentAbbrev': 'DET',
#               'opponentCommonName': {'default': 'Red Wings'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': -2,
#               'points': 1,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 0,
#               'shifts': 20,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 5,
#               'teamAbbrev': 'WSH',
#               'toi': '15:59'},
#              {'assists': 0,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2024-02-26',
#               'gameId': 2023020923,
#               'gameWinningGoals': 0,
#               'goals': 0,
#               'homeRoadFlag': 'H',
#               'opponentAbbrev': 'OTT',
#               'opponentCommonName': {'default': 'Senators', 'fr': 'Sénateurs'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': -3,
#               'points': 0,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 0,
#               'shifts': 19,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 0,
#               'teamAbbrev': 'WSH',
#               'toi': '16:37'},
#              {'assists': 0,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2024-02-24',
#               'gameId': 2023020906,
#               'gameWinningGoals': 0,
#               'goals': 0,
#               'homeRoadFlag': 'R',
#               'opponentAbbrev': 'FLA',
#               'opponentCommonName': {'default': 'Panthers'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': -1,
#               'points': 0,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 0,
#               'shifts': 21,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 4,
#               'teamAbbrev': 'WSH',
#               'toi': '18:06'},
#              {'assists': 1,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2024-02-22',
#               'gameId': 2023020894,
#               'gameWinningGoals': 0,
#               'goals': 0,
#               'homeRoadFlag': 'R',
#               'opponentAbbrev': 'TBL',
#               'opponentCommonName': {'default': 'Lightning'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': -1,
#               'points': 1,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 0,
#               'shifts': 21,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 6,
#               'teamAbbrev': 'WSH',
#               'toi': '22:10'},
#              {'assists': 1,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2024-02-20',
#               'gameId': 2023020879,
#               'gameWinningGoals': 0,
#               'goals': 2,
#               'homeRoadFlag': 'H',
#               'opponentAbbrev': 'NJD',
#               'opponentCommonName': {'default': 'Devils'},
#               'otGoals': 0,
#               'pim': 2,
#               'plusMinus': 1,
#               'points': 3,
#               'powerPlayGoals': 1,
#               'powerPlayPoints': 1,
#               'shifts': 23,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 5,
#               'teamAbbrev': 'WSH',
#               'toi': '17:59'},
#              {'assists': 1,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2024-02-17',
#               'gameId': 2023020857,
#               'gameWinningGoals': 0,
#               'goals': 0,
#               'homeRoadFlag': 'R',
#               'opponentAbbrev': 'MTL',
#               'opponentCommonName': {'default': 'Canadiens'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': 0,
#               'points': 1,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 1,
#               'shifts': 20,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 3,
#               'teamAbbrev': 'WSH',
#               'toi': '17:22'},
#              {'assists': 0,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2024-02-13',
#               'gameId': 2023020828,
#               'gameWinningGoals': 0,
#               'goals': 1,
#               'homeRoadFlag': 'H',
#               'opponentAbbrev': 'COL',
#               'opponentCommonName': {'default': 'Avalanche'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': -2,
#               'points': 1,
#               'powerPlayGoals': 1,
#               'powerPlayPoints': 1,
#               'shifts': 23,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 3,
#               'teamAbbrev': 'WSH',
#               'toi': '20:19'},
#              {'assists': 0,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2024-02-11',
#               'gameId': 2023020818,
#               'gameWinningGoals': 0,
#               'goals': 1,
#               'homeRoadFlag': 'H',
#               'opponentAbbrev': 'VAN',
#               'opponentCommonName': {'default': 'Canucks'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': 1,
#               'points': 1,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 0,
#               'shifts': 20,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 3,
#               'teamAbbrev': 'WSH',
#               'toi': '17:46'},
#              {'assists': 1,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2024-02-10',
#               'gameId': 2023020808,
#               'gameWinningGoals': 0,
#               'goals': 1,
#               'homeRoadFlag': 'R',
#               'opponentAbbrev': 'BOS',
#               'opponentCommonName': {'default': 'Bruins'},
#               'otGoals': 0,
#               'pim': 2,
#               'plusMinus': 2,
#               'points': 2,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 0,
#               'shifts': 20,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 4,
#               'teamAbbrev': 'WSH',
#               'toi': '19:09'},
#              {'assists': 0,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2024-02-08',
#               'gameId': 2023020795,
#               'gameWinningGoals': 0,
#               'goals': 1,
#               'homeRoadFlag': 'R',
#               'opponentAbbrev': 'FLA',
#               'opponentCommonName': {'default': 'Panthers'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': -2,
#               'points': 1,
#               'powerPlayGoals': 1,
#               'powerPlayPoints': 1,
#               'shifts': 18,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 3,
#               'teamAbbrev': 'WSH',
#               'toi': '19:30'},
#              {'assists': 0,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2024-02-06',
#               'gameId': 2023020789,
#               'gameWinningGoals': 0,
#               'goals': 1,
#               'homeRoadFlag': 'H',
#               'opponentAbbrev': 'MTL',
#               'opponentCommonName': {'default': 'Canadiens'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': 1,
#               'points': 1,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 0,
#               'shifts': 22,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 6,
#               'teamAbbrev': 'WSH',
#               'toi': '22:49'},
#              {'assists': 1,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2024-01-27',
#               'gameId': 2023020760,
#               'gameWinningGoals': 0,
#               'goals': 1,
#               'homeRoadFlag': 'R',
#               'opponentAbbrev': 'DAL',
#               'opponentCommonName': {'default': 'Stars'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': -2,
#               'points': 2,
#               'powerPlayGoals': 1,
#               'powerPlayPoints': 1,
#               'shifts': 24,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 4,
#               'teamAbbrev': 'WSH',
#               'toi': '19:32'},
#              {'assists': 1,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2024-01-24',
#               'gameId': 2023020742,
#               'gameWinningGoals': 0,
#               'goals': 0,
#               'homeRoadFlag': 'R',
#               'opponentAbbrev': 'COL',
#               'opponentCommonName': {'default': 'Avalanche'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': -2,
#               'points': 1,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 0,
#               'shifts': 19,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 0,
#               'teamAbbrev': 'WSH',
#               'toi': '19:38'},
#              {'assists': 0,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2024-01-23',
#               'gameId': 2023020734,
#               'gameWinningGoals': 0,
#               'goals': 0,
#               'homeRoadFlag': 'R',
#               'opponentAbbrev': 'MIN',
#               'opponentCommonName': {'default': 'Wild'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': -2,
#               'points': 0,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 0,
#               'shifts': 18,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 3,
#               'teamAbbrev': 'WSH',
#               'toi': '18:51'},
#              {'assists': 0,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2024-01-20',
#               'gameId': 2023020713,
#               'gameWinningGoals': 0,
#               'goals': 0,
#               'homeRoadFlag': 'R',
#               'opponentAbbrev': 'STL',
#               'opponentCommonName': {'default': 'Blues'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': -1,
#               'points': 0,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 0,
#               'shifts': 21,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 2,
#               'teamAbbrev': 'WSH',
#               'toi': '21:45'},
#              {'assists': 1,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2024-01-18',
#               'gameId': 2023020696,
#               'gameWinningGoals': 0,
#               'goals': 0,
#               'homeRoadFlag': 'H',
#               'opponentAbbrev': 'STL',
#               'opponentCommonName': {'default': 'Blues'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': 1,
#               'points': 1,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 0,
#               'shifts': 18,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 3,
#               'teamAbbrev': 'WSH',
#               'toi': '15:25'},
#              {'assists': 1,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2024-01-11',
#               'gameId': 2023020645,
#               'gameWinningGoals': 0,
#               'goals': 0,
#               'homeRoadFlag': 'H',
#               'opponentAbbrev': 'SEA',
#               'opponentCommonName': {'default': 'Kraken'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': 0,
#               'points': 1,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 0,
#               'shifts': 19,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 5,
#               'teamAbbrev': 'WSH',
#               'toi': '16:40'},
#              {'assists': 1,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2024-01-07',
#               'gameId': 2023020618,
#               'gameWinningGoals': 0,
#               'goals': 0,
#               'homeRoadFlag': 'H',
#               'opponentAbbrev': 'LAK',
#               'opponentCommonName': {'default': 'Kings'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': 0,
#               'points': 1,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 0,
#               'shifts': 23,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 0,
#               'teamAbbrev': 'WSH',
#               'toi': '17:29'},
#              {'assists': 1,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2024-01-05',
#               'gameId': 2023020603,
#               'gameWinningGoals': 0,
#               'goals': 0,
#               'homeRoadFlag': 'H',
#               'opponentAbbrev': 'CAR',
#               'opponentCommonName': {'default': 'Hurricanes'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': -1,
#               'points': 1,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 1,
#               'shifts': 20,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 1,
#               'teamAbbrev': 'WSH',
#               'toi': '15:57'},
#              {'assists': 2,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2024-01-03',
#               'gameId': 2023020587,
#               'gameWinningGoals': 0,
#               'goals': 0,
#               'homeRoadFlag': 'H',
#               'opponentAbbrev': 'NJD',
#               'opponentCommonName': {'default': 'Devils'},
#               'otGoals': 0,
#               'pim': 2,
#               'plusMinus': -1,
#               'points': 2,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 1,
#               'shifts': 22,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 3,
#               'teamAbbrev': 'WSH',
#               'toi': '21:15'},
#              {'assists': 0,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2024-01-02',
#               'gameId': 2023020576,
#               'gameWinningGoals': 1,
#               'goals': 1,
#               'homeRoadFlag': 'R',
#               'opponentAbbrev': 'PIT',
#               'opponentCommonName': {'default': 'Penguins'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': 0,
#               'points': 1,
#               'powerPlayGoals': 1,
#               'powerPlayPoints': 1,
#               'shifts': 19,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 4,
#               'teamAbbrev': 'WSH',
#               'toi': '16:44'},
#              {'assists': 0,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2023-12-30',
#               'gameId': 2023020562,
#               'gameWinningGoals': 0,
#               'goals': 1,
#               'homeRoadFlag': 'H',
#               'opponentAbbrev': 'NSH',
#               'opponentCommonName': {'default': 'Predators'},
#               'otGoals': 0,
#               'pim': 2,
#               'plusMinus': 0,
#               'points': 1,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 0,
#               'shifts': 24,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 2,
#               'teamAbbrev': 'WSH',
#               'toi': '22:06'},
#              {'assists': 0,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2023-12-29',
#               'gameId': 2023020550,
#               'gameWinningGoals': 0,
#               'goals': 0,
#               'homeRoadFlag': 'R',
#               'opponentAbbrev': 'NYI',
#               'opponentCommonName': {'default': 'Islanders'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': -1,
#               'points': 0,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 0,
#               'shifts': 17,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 1,
#               'teamAbbrev': 'WSH',
#               'toi': '17:06'},
#              {'assists': 0,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2023-12-27',
#               'gameId': 2023020529,
#               'gameWinningGoals': 0,
#               'goals': 0,
#               'homeRoadFlag': 'R',
#               'opponentAbbrev': 'NYR',
#               'opponentCommonName': {'default': 'Rangers'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': -1,
#               'points': 0,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 0,
#               'shifts': 21,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 4,
#               'teamAbbrev': 'WSH',
#               'toi': '16:50'},
#              {'assists': 0,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2023-12-23',
#               'gameId': 2023020521,
#               'gameWinningGoals': 0,
#               'goals': 0,
#               'homeRoadFlag': 'H',
#               'opponentAbbrev': 'TBL',
#               'opponentCommonName': {'default': 'Lightning'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': -1,
#               'points': 0,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 0,
#               'shifts': 21,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 3,
#               'teamAbbrev': 'WSH',
#               'toi': '19:43'},
#              {'assists': 1,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2023-12-21',
#               'gameId': 2023020499,
#               'gameWinningGoals': 1,
#               'goals': 1,
#               'homeRoadFlag': 'R',
#               'opponentAbbrev': 'CBJ',
#               'opponentCommonName': {'default': 'Blue Jackets'},
#               'otGoals': 1,
#               'pim': 0,
#               'plusMinus': -1,
#               'points': 2,
#               'powerPlayGoals': 1,
#               'powerPlayPoints': 2,
#               'shifts': 21,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 7,
#               'teamAbbrev': 'WSH',
#               'toi': '21:08'},
#              {'assists': 1,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2023-12-20',
#               'gameId': 2023020496,
#               'gameWinningGoals': 0,
#               'goals': 0,
#               'homeRoadFlag': 'H',
#               'opponentAbbrev': 'NYI',
#               'opponentCommonName': {'default': 'Islanders'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': -2,
#               'points': 1,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 1,
#               'shifts': 20,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 5,
#               'teamAbbrev': 'WSH',
#               'toi': '19:01'},
#              {'assists': 0,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2023-12-17',
#               'gameId': 2023020475,
#               'gameWinningGoals': 0,
#               'goals': 0,
#               'homeRoadFlag': 'R',
#               'opponentAbbrev': 'CAR',
#               'opponentCommonName': {'default': 'Hurricanes'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': 1,
#               'points': 0,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 0,
#               'shifts': 24,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 4,
#               'teamAbbrev': 'WSH',
#               'toi': '20:45'},
#              {'assists': 1,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2023-12-16',
#               'gameId': 2023020468,
#               'gameWinningGoals': 0,
#               'goals': 0,
#               'homeRoadFlag': 'R',
#               'opponentAbbrev': 'NSH',
#               'opponentCommonName': {'default': 'Predators'},
#               'otGoals': 0,
#               'pim': 2,
#               'plusMinus': -1,
#               'points': 1,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 1,
#               'shifts': 21,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 6,
#               'teamAbbrev': 'WSH',
#               'toi': '23:07'},
#              {'assists': 0,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2023-12-14',
#               'gameId': 2023020448,
#               'gameWinningGoals': 0,
#               'goals': 0,
#               'homeRoadFlag': 'R',
#               'opponentAbbrev': 'PHI',
#               'opponentCommonName': {'default': 'Flyers'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': -1,
#               'points': 0,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 0,
#               'shifts': 22,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 4,
#               'teamAbbrev': 'WSH',
#               'toi': '22:10'},
#              {'assists': 1,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2023-12-10',
#               'gameId': 2023020422,
#               'gameWinningGoals': 0,
#               'goals': 0,
#               'homeRoadFlag': 'R',
#               'opponentAbbrev': 'CHI',
#               'opponentCommonName': {'default': 'Blackhawks'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': 0,
#               'points': 1,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 0,
#               'shifts': 18,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 2,
#               'teamAbbrev': 'WSH',
#               'toi': '18:04'},
#              {'assists': 0,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2023-12-09',
#               'gameId': 2023020414,
#               'gameWinningGoals': 0,
#               'goals': 0,
#               'homeRoadFlag': 'H',
#               'opponentAbbrev': 'NYR',
#               'opponentCommonName': {'default': 'Rangers'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': 1,
#               'points': 0,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 0,
#               'shifts': 19,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 4,
#               'teamAbbrev': 'WSH',
#               'toi': '19:14'},
#              {'assists': 1,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2023-12-07',
#               'gameId': 2023020396,
#               'gameWinningGoals': 0,
#               'goals': 0,
#               'homeRoadFlag': 'H',
#               'opponentAbbrev': 'DAL',
#               'opponentCommonName': {'default': 'Stars'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': 0,
#               'points': 1,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 1,
#               'shifts': 21,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 3,
#               'teamAbbrev': 'WSH',
#               'toi': '17:49'},
#              {'assists': 0,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2023-12-04',
#               'gameId': 2023020378,
#               'gameWinningGoals': 0,
#               'goals': 0,
#               'homeRoadFlag': 'R',
#               'opponentAbbrev': 'ARI',
#               'opponentCommonName': {'default': 'Coyotes'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': -1,
#               'points': 0,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 0,
#               'shifts': 19,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 3,
#               'teamAbbrev': 'WSH',
#               'toi': '19:31'},
#              {'assists': 0,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2023-12-02',
#               'gameId': 2023020368,
#               'gameWinningGoals': 0,
#               'goals': 0,
#               'homeRoadFlag': 'R',
#               'opponentAbbrev': 'VGK',
#               'opponentCommonName': {'default': 'Golden Knights'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': -1,
#               'points': 0,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 0,
#               'shifts': 21,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 1,
#               'teamAbbrev': 'WSH',
#               'toi': '15:32'},
#              {'assists': 2,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2023-11-30',
#               'gameId': 2023020352,
#               'gameWinningGoals': 0,
#               'goals': 0,
#               'homeRoadFlag': 'R',
#               'opponentAbbrev': 'ANA',
#               'opponentCommonName': {'default': 'Ducks'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': -2,
#               'points': 2,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 2,
#               'shifts': 21,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 5,
#               'teamAbbrev': 'WSH',
#               'toi': '14:45'},
#              {'assists': 0,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2023-11-29',
#               'gameId': 2023020339,
#               'gameWinningGoals': 0,
#               'goals': 0,
#               'homeRoadFlag': 'R',
#               'opponentAbbrev': 'LAK',
#               'opponentCommonName': {'default': 'Kings'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': 0,
#               'points': 0,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 0,
#               'shifts': 18,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 2,
#               'teamAbbrev': 'WSH',
#               'toi': '13:37'},
#              {'assists': 0,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2023-11-27',
#               'gameId': 2023020326,
#               'gameWinningGoals': 0,
#               'goals': 0,
#               'homeRoadFlag': 'R',
#               'opponentAbbrev': 'SJS',
#               'opponentCommonName': {'default': 'Sharks'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': -1,
#               'points': 0,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 0,
#               'shifts': 19,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 5,
#               'teamAbbrev': 'WSH',
#               'toi': '22:02'},
#              {'assists': 0,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2023-11-24',
#               'gameId': 2023020298,
#               'gameWinningGoals': 0,
#               'goals': 0,
#               'homeRoadFlag': 'H',
#               'opponentAbbrev': 'EDM',
#               'opponentCommonName': {'default': 'Oilers'},
#               'otGoals': 0,
#               'pim': 2,
#               'plusMinus': -1,
#               'points': 0,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 0,
#               'shifts': 20,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 3,
#               'teamAbbrev': 'WSH',
#               'toi': '23:54'},
#              {'assists': 0,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2023-11-22',
#               'gameId': 2023020285,
#               'gameWinningGoals': 0,
#               'goals': 0,
#               'homeRoadFlag': 'H',
#               'opponentAbbrev': 'BUF',
#               'opponentCommonName': {'default': 'Sabres'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': 0,
#               'points': 0,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 0,
#               'shifts': 21,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 4,
#               'teamAbbrev': 'WSH',
#               'toi': '20:19'},
#              {'assists': 0,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2023-11-18',
#               'gameId': 2023020263,
#               'gameWinningGoals': 0,
#               'goals': 1,
#               'homeRoadFlag': 'H',
#               'opponentAbbrev': 'CBJ',
#               'opponentCommonName': {'default': 'Blue Jackets'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': 0,
#               'points': 1,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 0,
#               'shifts': 19,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 2,
#               'teamAbbrev': 'WSH',
#               'toi': '15:02'},
#              {'assists': 0,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2023-11-14',
#               'gameId': 2023020232,
#               'gameWinningGoals': 0,
#               'goals': 0,
#               'homeRoadFlag': 'H',
#               'opponentAbbrev': 'VGK',
#               'opponentCommonName': {'default': 'Golden Knights'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': 1,
#               'points': 0,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 0,
#               'shifts': 22,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 3,
#               'teamAbbrev': 'WSH',
#               'toi': '21:59'},
#              {'assists': 0,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2023-11-11',
#               'gameId': 2023020216,
#               'gameWinningGoals': 0,
#               'goals': 2,
#               'homeRoadFlag': 'R',
#               'opponentAbbrev': 'NYI',
#               'opponentCommonName': {'default': 'Islanders'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': 2,
#               'points': 2,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 0,
#               'shifts': 19,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 5,
#               'teamAbbrev': 'WSH',
#               'toi': '18:09'},
#              {'assists': 1,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2023-11-10',
#               'gameId': 2023020206,
#               'gameWinningGoals': 0,
#               'goals': 0,
#               'homeRoadFlag': 'R',
#               'opponentAbbrev': 'NJD',
#               'opponentCommonName': {'default': 'Devils'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': 1,
#               'points': 1,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 0,
#               'shifts': 23,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 3,
#               'teamAbbrev': 'WSH',
#               'toi': '21:19'},
#              {'assists': 0,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2023-11-08',
#               'gameId': 2023020191,
#               'gameWinningGoals': 0,
#               'goals': 0,
#               'homeRoadFlag': 'H',
#               'opponentAbbrev': 'FLA',
#               'opponentCommonName': {'default': 'Panthers'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': -1,
#               'points': 0,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 0,
#               'shifts': 25,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 2,
#               'teamAbbrev': 'WSH',
#               'toi': '22:31'},
#              {'assists': 0,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2023-11-04',
#               'gameId': 2023020166,
#               'gameWinningGoals': 0,
#               'goals': 0,
#               'homeRoadFlag': 'H',
#               'opponentAbbrev': 'CBJ',
#               'opponentCommonName': {'default': 'Blue Jackets'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': 0,
#               'points': 0,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 0,
#               'shifts': 19,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 3,
#               'teamAbbrev': 'WSH',
#               'toi': '20:41'},
#              {'assists': 0,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2023-11-02',
#               'gameId': 2023020150,
#               'gameWinningGoals': 0,
#               'goals': 0,
#               'homeRoadFlag': 'H',
#               'opponentAbbrev': 'NYI',
#               'opponentCommonName': {'default': 'Islanders'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': -3,
#               'points': 0,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 0,
#               'shifts': 19,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 3,
#               'teamAbbrev': 'WSH',
#               'toi': '19:29'},
#              {'assists': 2,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2023-10-29',
#               'gameId': 2023020128,
#               'gameWinningGoals': 0,
#               'goals': 0,
#               'homeRoadFlag': 'H',
#               'opponentAbbrev': 'SJS',
#               'opponentCommonName': {'default': 'Sharks'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': 2,
#               'points': 2,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 0,
#               'shifts': 23,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 7,
#               'teamAbbrev': 'WSH',
#               'toi': '22:20'},
#              {'assists': 1,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2023-10-27',
#               'gameId': 2023020114,
#               'gameWinningGoals': 0,
#               'goals': 0,
#               'homeRoadFlag': 'H',
#               'opponentAbbrev': 'MIN',
#               'opponentCommonName': {'default': 'Wild'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': 0,
#               'points': 1,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 1,
#               'shifts': 25,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 3,
#               'teamAbbrev': 'WSH',
#               'toi': '22:23'},
#              {'assists': 1,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2023-10-25',
#               'gameId': 2023020099,
#               'gameWinningGoals': 0,
#               'goals': 1,
#               'homeRoadFlag': 'R',
#               'opponentAbbrev': 'NJD',
#               'opponentCommonName': {'default': 'Devils'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': 2,
#               'points': 2,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 0,
#               'shifts': 22,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 4,
#               'teamAbbrev': 'WSH',
#               'toi': '20:05'},
#              {'assists': 0,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2023-10-24',
#               'gameId': 2023020083,
#               'gameWinningGoals': 0,
#               'goals': 1,
#               'homeRoadFlag': 'H',
#               'opponentAbbrev': 'TOR',
#               'opponentCommonName': {'default': 'Maple Leafs'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': 0,
#               'points': 1,
#               'powerPlayGoals': 1,
#               'powerPlayPoints': 1,
#               'shifts': 20,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 14,
#               'teamAbbrev': 'WSH',
#               'toi': '19:43'},
#              {'assists': 1,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2023-10-21',
#               'gameId': 2023020069,
#               'gameWinningGoals': 0,
#               'goals': 0,
#               'homeRoadFlag': 'R',
#               'opponentAbbrev': 'MTL',
#               'opponentCommonName': {'default': 'Canadiens'},
#               'otGoals': 0,
#               'pim': 2,
#               'plusMinus': 1,
#               'points': 1,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 0,
#               'shifts': 20,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 5,
#               'teamAbbrev': 'WSH',
#               'toi': '19:58'},
#              {'assists': 1,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2023-10-18',
#               'gameId': 2023020049,
#               'gameWinningGoals': 0,
#               'goals': 0,
#               'homeRoadFlag': 'R',
#               'opponentAbbrev': 'OTT',
#               'opponentCommonName': {'default': 'Senators', 'fr': 'Sénateurs'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': -1,
#               'points': 1,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 0,
#               'shifts': 20,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 0,
#               'teamAbbrev': 'WSH',
#               'toi': '18:33'},
#              {'assists': 0,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2023-10-16',
#               'gameId': 2023020039,
#               'gameWinningGoals': 0,
#               'goals': 0,
#               'homeRoadFlag': 'H',
#               'opponentAbbrev': 'CGY',
#               'opponentCommonName': {'default': 'Flames'},
#               'otGoals': 0,
#               'pim': 0,
#               'plusMinus': 0,
#               'points': 0,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 0,
#               'shifts': 20,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 0,
#               'teamAbbrev': 'WSH',
#               'toi': '20:04'},
#              {'assists': 0,
#               'commonName': {'default': 'Capitals'},
#               'gameDate': '2023-10-13',
#               'gameId': 2023020018,
#               'gameWinningGoals': 0,
#               'goals': 0,
#               'homeRoadFlag': 'H',
#               'opponentAbbrev': 'PIT',
#               'opponentCommonName': {'default': 'Penguins'},
#               'otGoals': 0,
#               'pim': 2,
#               'plusMinus': -1,
#               'points': 0,
#               'powerPlayGoals': 0,
#               'powerPlayPoints': 0,
#               'shifts': 21,
#               'shorthandedGoals': 0,
#               'shorthandedPoints': 0,
#               'shots': 4,
#               'teamAbbrev': 'WSH',
#               'toi': '18:42'}],
#  'gameTypeId': 2,
#  'playerStatsSeasons': [{'gameTypes': [2], 'season': 20242025},
#                         {'gameTypes': [2, 3], 'season': 20232024},
#                         {'gameTypes': [2], 'season': 20222023},
#                         {'gameTypes': [2, 3], 'season': 20212022},
#                         {'gameTypes': [2, 3], 'season': 20202021},
#                         {'gameTypes': [2, 3], 'season': 20192020},
#                         {'gameTypes': [2, 3], 'season': 20182019},
#                         {'gameTypes': [2, 3], 'season': 20172018},
#                         {'gameTypes': [2, 3], 'season': 20162017},
#                         {'gameTypes': [2, 3], 'season': 20152016},
#                         {'gameTypes': [2, 3], 'season': 20142015},
#                         {'gameTypes': [2], 'season': 20132014},
#                         {'gameTypes': [2, 3], 'season': 20122013},
#                         {'gameTypes': [2, 3], 'season': 20112012},
#                         {'gameTypes': [2, 3], 'season': 20102011},
#                         {'gameTypes': [2, 3], 'season': 20092010},
#                         {'gameTypes': [2, 3], 'season': 20082009},
#                         {'gameTypes': [2, 3], 'season': 20072008},
#                         {'gameTypes': [2], 'season': 20062007},
#                         {'gameTypes': [2], 'season': 20052006}],
#  'seasonId': 20232024}

# %%
# Create a DataFrame from the game log data
game_log_df = pd.DataFrame(game_logs)

game_log_df.head()

# %%
# Function to get game logs for a specific season
def get_goalie_game_log(player_id, season):
    url = f"https://api-web.nhle.com/v1/goalie-stats-leaders/current?categories=wins&limit=5"
    response = requests.get(url)
    return response.json()

# %%
teams = [
#     
    "BOS",  # Boston Bruins
      #"ANA",  # Anaheim Ducks
    "BUF",  # Buffalo Sabres
    "CAR",  # Carolina Hurricanes
    "CBJ",  # Columbus Blue Jackets
    "CGY",  # Calgary Flames
    "CHI",  # Chicago Blackhawks
    "COL",  # Colorado Avalanche
    "DAL",  # Dallas Stars
    "DET",  # Detroit Red Wings
                                    #"EDM",  # Edmonton Oilers
    "FLA",  # Florida Panthers
    "LAK",  # Los Angeles Kings
    "MIN",  # Minnesota Wild
    "MTL",  # Montreal Canadiens
    "NJD",  # New Jersey Devils
    "NSH",  # Nashville Predators
    "NYI",  # New York Islanders
                                    #"NYR",  # New York Rangers
    "OTT",  # Ottawa Senators
    "PHI",  # Philadelphia Flyers
    "PIT",  # Pittsburgh Penguins
    "SEA",  # Seattle Kraken
    "SJS",  # San Jose Sharks
    "STL",  # St. Louis Blues
    "TBL",  # Tampa Bay Lightning
    "TOR",  # Toronto Maple Leafs
    "UTA",  # Utah Hockey Club
    "VAN",  # Vancouver Canucks
    "VGK",  # Vegas Golden Knights
    "WPG",  # Winnipeg Jets
    "WSH"   # Washington Capitals
#     "ARI"   # Arizona Coyotes
#     "ATL"   # Atlanta Thrashers 
#     "HFD"   # Hartford
#     "PHX"   # Pheonix
#     "QUE"   # Quebec
#     "WIN"   # Winnepeg Jets - Old
    ]

seasons = [

    "20242025"
]

# Function to get player data from the NHL API
def get_player_data(team, season):
    url = f"https://api-web.nhle.com/v1/roster/{team}/{season}"
    response = requests.get(url)

    # Check if the response is valid JSON
    try:
        return response.json()
    except requests.JSONDecodeError:
        print(f"Error decoding JSON for team {team} in season {season}")
        return {}

# Initialize a dictionary to store player IDs
player_ids = {}

# Loop through each season in the seasons list
for season in seasons:
    player_ids[season] = {}

    # Loop through each team
    for team in teams:
        try:
            # Get the player data for the team and season
            player_data = get_player_data(team, season)
        
            # Initialize dictionaries for defencemen, forwards, and goalies
            player_ids[season][team] = {
                #'defencemen': [],
                #'forwards': [],
                'goalies': []
            }
        
            # # Extract player IDs from defencemen
            # if 'defensemen' in player_data:
            #     for player in player_data['defensemen']:
            #         player_id = player['id']
            #         player_ids[season][team]['defencemen'].append(player_id)
        
            # Extract player IDs from forwards
            # if 'forwards' in player_data:
            #     for player in player_data['forwards']:
            #         player_id = player['id']
            #         player_ids[season][team]['forwards'].append(player_id)
        
            # Extract player IDs from goalies
            if 'goalies' in player_data:
                for player in player_data['goalies']:
                    player_id = player['id']
                    player_ids[season][team]['goalies'].append(player_id)
    
        except KeyError:
            print(f"Team {team} not found for season {season}. Skipping...")
            continue

#Print the player IDs
pprint(player_ids)
# Out:
# {'20242025': {'BOS': {'goalies': [8476914, 8480280]},
#               'BUF': {'goalies': [8480045, 8473503]},
#               'CAR': {'goalies': [8475883, 8481611]},
#               'CBJ': {'goalies': [8478007, 8480193]},
#               'CGY': {'goalies': [8478435, 8481692]},
#               'CHI': {'goalies': [8481519, 8482821]},
#               'COL': {'goalies': [8478406, 8475809]},
#               'DAL': {'goalies': [8479193, 8479979]},
#               'DET': {'goalies': [8479312, 8475852, 8475660]},
#               'FLA': {'goalies': [8475683, 8477970]},
#               'LAK': {'goalies': [8475311, 8479496]},
#               'MIN': {'goalies': [8470594, 8479406]},
#               'MTL': {'goalies': [8482487, 8478470]},
#               'NJD': {'goalies': [8474596, 8474593]},
#               'NSH': {'goalies': [8481020, 8477424]},
#               'NYI': {'goalies': [8477405, 8478009, 8473575]},
#               'OTT': {'goalies': [8476341, 8482447, 8476999]},
#               'PHI': {'goalies': [8481035, 8478905]},
#               'PIT': {'goalies': [8477465, 8477968]},
#               'SEA': {'goalies': [8478916, 8475831]},
#               'SJS': {'goalies': [8480382, 8484312]},
#               'STL': {'goalies': [8476412, 8480981]},
#               'TBL': {'goalies': [8477992, 8476883]},
#               'TOR': {'goalies': [8476932, 8479361]},
#               'UTA': {'goalies': [8483530, 8478872]},
#               'VAN': {'goalies': [8477967, 8480947, 8481668]},
#               'VGK': {'goalies': [8478499, 8478492]},
#               'WPG': {'goalies': [8477480, 8476945]},
#               'WSH': {'goalies': [8479292, 8480313]}}}

# %%
# look at an individual goalie's stats
import requests
import pandas as pd

# Function to get game logs for a specific season
def get_game_log(player_id, season):
    url = f"https://api-web.nhle.com/v1/player/{player_id}/game-log/{season}/2"
    response = requests.get(url)
    
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error: Unable to fetch data for player_id {player_id} and season {season}")
        return None

# Specify the season and player_id
season = 20242025
player_id = 8476914

# Get the game logs
game_logs = get_game_log(player_id, season)

# Convert the game logs to a DataFrame and print the columns
if game_logs and 'gameLog' in game_logs:
    game_log_data = game_logs['gameLog']
    
    # Create a DataFrame from the game log data
    game_log_df = pd.DataFrame(game_log_data)
    
    # Display the columns of the DataFrame
    print("Columns in the game log DataFrame:")
    print(game_log_df.columns)
else:
    print("No game log data available")
# Out:
# Columns in the game log DataFrame:
# Index(['gameId', 'teamAbbrev', 'homeRoadFlag', 'gameDate', 'goals', 'assists',
#        'commonName', 'opponentCommonName', 'gamesStarted', 'decision',
#        'shotsAgainst', 'goalsAgainst', 'savePctg', 'shutouts',
#        'opponentAbbrev', 'pim', 'toi'],
#       dtype='object')

# %%
# Function to get game logs for a specific season
def get_game_log(player_id, season):
    url = f"https://api-web.nhle.com/v1/player/{player_id}/game-log/{season}/2"
    response = requests.get(url)
    return response.json()

# List of seasons Ovechkin played in
seasons = [
    # "20052006", "20062007", "20072008", "20082009", "20092010",
    # "20102011", "20112012", "20122013", "20132014", "20142015",
    # "20152016", "20162017", "20172018", "20182019", "20192020",
    # "20202021", "20212022", "20222023", "20232024", 
    "20242025"
]

# Player ID for Alexander Ovechkin
player_id = 8471214



# Collect game logs for all seasons and save to CSV files
for season in seasons:
    game_log = get_game_log(player_id, season)
    
    if game_log and 'gameLog' in game_log:
        game_log_data = game_log['gameLog']

        seasons_list = []
        
        for stat in game_log_data:
            stats_info = {
                'gameDate': stat.get('gameDate'),
                'homeRoadFlag': stat.get('homeRoadFlag'),	
                'goals': stat.get('goals'),	
                'assists': stat.get('assists'),	
                'points': stat.get('points'),	
                'plusMinus': stat.get('plusMinus'),	
                'powerPlayGoals': stat.get('powerPlayGoals'),	
                'powerPlayPoints': stat.get('powerPlayGoals'),	
                'gameWinningGoals': stat.get('gameWinningGoals'),	
                'otGoals': stat.get('otGoals'),	
                'shots': stat.get('shots'),	
                'shifts': stat.get('shifts'),	
                'opponentAbbrev': stat.get('opponentAbbrev'),	
                'pim': stat.get('pim'),	
                'toi': stat.get('toi'),
            }
            seasons_list.append(stats_info)
        
        # Create df from the flattened list of data
        seasons_df = pd.DataFrame(seasons_list)

        # Set gameDate as the index
        seasons_df.set_index('gameDate', inplace=True)
        
        # Save the DataFrame to a CSV file
        csv_filename = f'season_{season}.csv'
        seasons_df.to_csv(csv_filename)
        print(f"DataFrame for the {season} season saved to {csv_filename}")
    else:
        print(f"No valid data found for the {season} season")
# Out:
# DataFrame for the 20052006 season saved to season_20052006.csv
# DataFrame for the 20062007 season saved to season_20062007.csv
# DataFrame for the 20072008 season saved to season_20072008.csv
# DataFrame for the 20082009 season saved to season_20082009.csv
# DataFrame for the 20092010 season saved to season_20092010.csv
# DataFrame for the 20102011 season saved to season_20102011.csv
# DataFrame for the 20112012 season saved to season_20112012.csv
# DataFrame for the 20122013 season saved to season_20122013.csv
# DataFrame for the 20132014 season saved to season_20132014.csv
# DataFrame for the 20142015 season saved to season_20142015.csv
# DataFrame for the 20152016 season saved to season_20152016.csv
# DataFrame for the 20162017 season saved to season_20162017.csv
# DataFrame for the 20172018 season saved to season_20172018.csv
# DataFrame for the 20182019 season saved to season_20182019.csv
# DataFrame for the 20192020 season saved to season_20192020.csv
# DataFrame for the 20202021 season saved to season_20202021.csv
# DataFrame for the 20212022 season saved to season_20212022.csv
# DataFrame for the 20222023 season saved to season_20222023.csv
# DataFrame for the 20232024 season saved to season_20232024.csv
# DataFrame for the 20242025 season saved to season_20242025.csv

# %%
# Load in each season's csv file
season_05 = pd.read_csv('season_20052006.csv')
season_06 = pd.read_csv('season_20062007.csv')
season_07 = pd.read_csv('season_20072008.csv')
season_08 = pd.read_csv('season_20082009.csv')
season_09 = pd.read_csv('season_20092010.csv')
season_10 = pd.read_csv('season_20102011.csv')
season_11 = pd.read_csv('season_20112012.csv')
season_12 = pd.read_csv('season_20122013.csv')
season_13 = pd.read_csv('season_20132014.csv')
season_14 = pd.read_csv('season_20142015.csv')
season_15 = pd.read_csv('season_20152016.csv')
season_16 = pd.read_csv('season_20162017.csv')
season_17 = pd.read_csv('season_20172018.csv')
season_18 = pd.read_csv('season_20182019.csv')
season_19 = pd.read_csv('season_20192020.csv')
season_20 = pd.read_csv('season_20202021.csv')
season_21 = pd.read_csv('season_20212022.csv')
season_22 = pd.read_csv('season_20222023.csv')
season_23 = pd.read_csv('season_20232024.csv')
season_24 = pd.read_csv('season_20242025.csv')

# %%
season_06
# Out:
#       gameDate homeRoadFlag  goals  assists  points  plusMinus  \
# 0   2007-04-07            H      0        0       0          0
# 1   2007-04-04            R      2        0       2         -1
# 2   2007-04-03            H      1        0       1          1
# 3   2007-03-31            R      0        0       0         -2
# 4   2007-03-30            R      0        2       2          1
# ..         ...          ...    ...      ...     ...        ...
# 77  2006-10-18            H      0        0       0          1
# 78  2006-10-14            H      0        1       1          0
# 79  2006-10-12            R      0        1       1          1
# 80  2006-10-07            H      2        0       2          2
# 81  2006-10-05            R      0        0       0         -4
#
#     powerPlayGoals  powerPlayPoints  gameWinningGoals  otGoals  shots  shifts  \
# 0                0                0                 0        0      8      26
# 1                1                1                 1        0      4      26
# 2                0                0                 1        0      5      26
# 3                0                0                 0        0      3      23
# 4                0                0                 0        0      2      27
# ..             ...              ...               ...      ...    ...     ...
# 77               0                0                 0        0      4      26
# 78               0                0                 0        0      6      26
# 79               0                0                 0        0      6      25
# 80               1                1                 1        0     15      26
# 81               0                0                 0        0      3      29
#
#    opponentAbbrev  pim    toi
# 0             BUF    0  24:19
# 1             ATL    0  19:43
# 2             FLA    0  21:27
# 3             TBL    0  21:32
# 4             FLA    0  22:44
# ..            ...  ...    ...
# 77            FLA    0  19:36
# 78            ATL    0  20:54
# 79            MIN    0  20:47
# 80            CAR    0  21:41
# 81            NYR    2  24:01
#
# [82 rows x 15 columns]

# %%
season_dfs = {
    "20052006": season_05,
    "20062007": season_06,
    "20072008": season_07,
    "20082009": season_08,
    "20092010": season_09,
    "20102011": season_10,
    "20112012": season_11,
    "20122013": season_12,
    "20132014": season_13,
    "20142015": season_14,
    "20152016": season_15,
    "20162017": season_16,
    "20172018": season_17,
    "20182019": season_18,
    "20192020": season_19,
    "20202021": season_20,
    "20212022": season_21,
    "20222023": season_22,
    "20232024": season_23,
    "20242025": season_24,

}

#Function to drop the colon from the 'toi' column for each DataFrame
def drop_colon_from_toi(dfs):
    for season, df in dfs.items():
        df['toi'] = df['toi'].str.replace(':', '').astype(float)
         # Convert back to string and add the colon back
        #df['toi'] = df['toi'].astype(str).apply(lambda x: f"{x[:-2]}:{x[-2:]}")
       

# Apply the function to each DataFrame
drop_colon_from_toi(season_dfs)

# %%
season_09.head()
# Out:
#      gameDate homeRoadFlag  goals  assists  points  plusMinus  powerPlayGoals  \
# 0  2010-04-11            H      0        0       0         -1               0
# 1  2010-04-09            H      2        1       3          3               0
# 2  2010-04-06            R      2        0       2          1               1
# 3  2010-04-05            H      0        2       2          1               0
# 4  2010-04-03            R      0        0       0         -2               0
#
#    powerPlayPoints  gameWinningGoals  otGoals  shots  shifts opponentAbbrev  \
# 0                0                 0        0      5      21            BOS
# 1                0                 1        0      3      20            ATL
# 2                1                 0        0      4      22            PIT
# 3                0                 0        0      6      18            BOS
# 4                0                 0        0      2      18            CBJ
#
#    pim     toi
# 0    2  2555.0
# 1    0  2311.0
# 2    2  1922.0
# 3    0  1814.0
# 4    0  2350.0

# %%
# Assuming you have already loaded the data into DataFrames named season_05, season_06, ..., season_25
season_dfs = {
    "20052006": season_05,
    "20062007": season_06,
    "20072008": season_07,
    "20082009": season_08,
    "20092010": season_09,
    "20102011": season_10,
    "20112012": season_11,
    "20122013": season_12,
    "20132014": season_13,
    "20142015": season_14,
    "20152016": season_15,
    "20162017": season_16,
    "20172018": season_17,
    "20182019": season_18,
    "20192020": season_19,
    "20202021": season_20,
    "20212022": season_21,
    "20222023": season_22,
    "20232024": season_23,
    "20242025": season_24
}

# Function to create a new DataFrame grouped by homeRoadFlag
def create_grouped_df(df):
    grouped_df = df.groupby('homeRoadFlag').agg({
        'gameDate': 'count',
        'goals': 'sum',
        'assists': 'sum',
        'points': 'sum',
        'plusMinus': 'sum',
        'powerPlayGoals': 'sum',
        'powerPlayPoints': 'sum',
        'gameWinningGoals': 'sum',
        'otGoals': 'sum',
        'shots': 'sum',
        'shifts': 'sum',
        'pim': 'sum',
        'toi': lambda x: round(x.mean(), 0)  # Calculate mean of 'toi' in minutes and round to 2 decimals
    }).rename(columns={'gameDate': 'gameCount'})
    # Sum the grouped statistics to create a single row DataFrame
    single_row_df = grouped_df.sum().to_frame().T
    
    return single_row_df

# %%
# Loop through each DataFrame and create a grouped DataFrame
grouped_dfs = {}
for season, df in season_dfs.items():
    grouped_df = create_grouped_df(df)
    grouped_dfs[season] = grouped_df

# %%
# Create df for each season
ovi_05 = grouped_dfs.get('20052006')
ovi_06 = grouped_dfs.get('20062007')
ovi_07 = grouped_dfs.get('20072008')
ovi_08 = grouped_dfs.get('20082009')
ovi_09 = grouped_dfs.get('20092010')
ovi_10 = grouped_dfs.get('20102011')
ovi_11 = grouped_dfs.get('20112012')
ovi_12 = grouped_dfs.get('20122013')
ovi_13 = grouped_dfs.get('20132014')
ovi_14 = grouped_dfs.get('20142015')
ovi_15 = grouped_dfs.get('20152016')
ovi_16 = grouped_dfs.get('20162017')
ovi_17 = grouped_dfs.get('20172018')
ovi_18 = grouped_dfs.get('20182019')
ovi_19 = grouped_dfs.get('20192020')
ovi_20 = grouped_dfs.get('20202021')
ovi_21 = grouped_dfs.get('20212022')
ovi_22 = grouped_dfs.get('20222023')
ovi_23 = grouped_dfs.get('20232024')
ovi_24 = grouped_dfs.get('20242025')

# %%
ovi_22
# Out:
#    gameCount  goals  assists  points  plusMinus  powerPlayGoals  \
# 0       73.0   42.0     33.0    75.0      -16.0            14.0
#
#    powerPlayPoints  gameWinningGoals  otGoals  shots  shifts   pim     toi
# 0             14.0               3.0      1.0  294.0  1591.0  48.0  4002.0

# %%
import pandas as pd

# Assuming grouped_dfs is your dictionary of grouped DataFrames
grouped_dfs = {
    "20052006": ovi_05,
    "20062007": ovi_06,
    "20072008": ovi_07,
    "20082009": ovi_08,
    "20092010": ovi_09,
    "20102011": ovi_10,
    "20112012": ovi_11,
    "20122013": ovi_12,
    "20132014": ovi_13,
    "20142015": ovi_14,
    "20152016": ovi_15,
    "20162017": ovi_16,
    "20172018": ovi_17,
    "20182019": ovi_18,
    "20192020": ovi_19,
    "20202021": ovi_20,
    "20212022": ovi_21,
    "20222023": ovi_22,
    "20232024": ovi_23,
    "20242025": ovi_24,
}

# Function to convert float 'toi' to 'MM:SS' format
def convert_float_to_mm_ss(df):
    def float_to_mm_ss(minutes):
        mins = int(minutes // 60)
        secs = int(minutes % 60)
        return f"{mins:02}:{secs}"
    
    df['toi'] = df['toi'].astype(float).apply(float_to_mm_ss)
    return df

# Apply the function to each DataFrame
for season, df in season_dfs.items():
    season_dfs[season] = convert_float_to_mm_ss(df)
    

# Create individual DataFrames for each season
ovi_05 = grouped_dfs.get('20052006')
ovi_06 = grouped_dfs.get('20062007')
ovi_07 = grouped_dfs.get('20072008')
ovi_08 = grouped_dfs.get('20082009')
ovi_09 = grouped_dfs.get('20092010')
ovi_10 = grouped_dfs.get('20102011')
ovi_11 = grouped_dfs.get('20112012')
ovi_12 = grouped_dfs.get('20122013')
ovi_13 = grouped_dfs.get('20132014')
ovi_14 = grouped_dfs.get('20142015')
ovi_15 = grouped_dfs.get('20152016')
ovi_16 = grouped_dfs.get('20162017')
ovi_17 = grouped_dfs.get('20172018')
ovi_18 = grouped_dfs.get('20182019')
ovi_19 = grouped_dfs.get('20192020')
ovi_20 = grouped_dfs.get('20202021')
ovi_21 = grouped_dfs.get('20212022')
ovi_22 = grouped_dfs.get('20222023')
ovi_23 = grouped_dfs.get('20232024')
ovi_24 = grouped_dfs.get('20242025')

# %%
ovi_05['shots_per_game'] = ovi_05['shots'] / ovi_05['gameCount']
ovi_05_no_toi = ovi_05.drop(columns=['toi', 'shifts', 'shots'])
ovi_05_no_toi
# Out:
#    gameCount  goals  assists  points  plusMinus  powerPlayGoals  \
# 0       81.0   52.0     54.0   106.0        2.0            21.0
#
#    powerPlayPoints  gameWinningGoals  otGoals   pim  shots_per_game
# 0             21.0               5.0      2.0  52.0        5.246914

# %%
# Create the grouped DataFrame
grouped_df = ovi_05_no_toi

# Labels for the radar chart
labels = grouped_df.columns.tolist()
markers = [0, 1, 2, 3, 4, 5]
str_markers = ["0", "1", "2", "3", "4", "5"]

# Function to create a radar chart
def make_radar_chart(name, stats, attribute_labels=labels, plot_markers=markers, plot_str_markers=str_markers):
    labels = np.array(attribute_labels)
    angles = np.linspace(0, 2 * np.pi, len(labels), endpoint=False).tolist()
    
    # The plot is a circle, so we need to "complete the loop"
    stats = np.concatenate((stats, [stats[0]]))
    angles += angles[:1]
    
    fig, ax = plt.subplots(figsize=(6, 6), subplot_kw=dict(polar=True))
    ax.plot(angles, stats, 'o-', linewidth=2)
    ax.fill(angles, stats, alpha=0.25)
    ax.set_thetagrids(np.degrees(angles[:-1]), labels)
    plt.yticks(plot_markers)
    ax.set_title(name)
    ax.grid(True)
    
    plt.show()

# Calculate the values for the radar chart
stats = grouped_df.iloc[0].values

# Create a radar chart for the grouped_df DataFrame
make_radar_chart("Radar Plot for Ovi 05 No TOI", stats)
